# %% [markdown]
# # Task 5 :
# > - Build 2–3 reusable plotting functions (a tiny personal visualization module).

# %%
from visualization import bar_chart, line_chart, pie_chart

# %% [markdown]
# # Bar Chart

# %%
# Example usage for a reusable bar chart function
labels = ["A", "B", "C", "D"]
values = [10, 15, 8, 12]
bar_chart(labels, values, title="Example Bar Chart", xlabel="Group", ylabel="Count")

# %% [markdown]
# # Line Chart

# %%
# Example usage for a reusable line chart function
labels = [1, 2, 3, 4, 5]
values = [2, 5, 4, 7, 9]
line_chart(labels, values, title="Example Line Chart", xlabel="X", ylabel="Y")

# %% [markdown]
# # Pie Chart

# %%
# Example usage for a reusable pie chart function
labels = ["Red", "Blue", "Green"]
values = [30, 45, 25]
pie_chart(labels, values, title="Example Pie Chart")
